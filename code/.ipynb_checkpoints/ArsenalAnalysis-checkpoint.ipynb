# %%
import pandas as pd
# %matplotlib inline

# %%
# Read the dataset of Premier League match results for the season 2018-2019 and store the results in a DataFrame
football_data = pd.read_csv('../data/EPL18_19.csv')

# %%
# ARSENAL DATA ONLY
# Since, I am only concerned with 'Arsenal' matches, I choose only those games where 
# ('HomeTeam' == 'Arsenal') OR ('AwayTeam' == 'Arsenal')
arsenal_data = football_data[(football_data['HomeTeam'] == 'Arsenal') | (football_data['AwayTeam'] == 'Arsenal')]
# Out:
#    Div        Date   HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 7   E0  12/08/2018    Arsenal  Man City     0     2   A     0     1   A  ...
# 11  E0  18/08/2018    Chelsea   Arsenal     3     2   H     2     2   D  ...
# 20  E0  25/08/2018    Arsenal  West Ham     3     1   H     1     1   D  ...
# 38  E0  02/09/2018    Cardiff   Arsenal     2     3   A     1     1   D  ...
# 44  E0  15/09/2018  Newcastle   Arsenal     1     2   A     0     0   D  ...
#
#    BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA
# 7      2.42    20   0.75     1.78     1.74     2.21     2.15  4.43  4.13  1.81
# 11     2.17    21  -0.75     2.08     2.03     1.88     1.84  1.83  3.84  4.64
# 20     2.73    21  -1.50     2.05     2.00     1.92     1.87  1.37  5.65  8.67
# 38     2.07    21   1.00     2.00     1.93     2.05     1.94  6.34  4.47  1.56
# 44     2.14    21   0.25     2.39     2.31     1.69     1.65  4.46  3.86  1.86
#
# [5 rows x 62 columns]

# %%
# Removing columns we do not require
arsenal_data = arsenal_data.loc[:,'Div':'AR']
arsenal_data.head()
# Out:
#    Div        Date   HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 7   E0  12/08/2018    Arsenal  Man City     0     2   A     0     1   A  ...
# 11  E0  18/08/2018    Chelsea   Arsenal     3     2   H     2     2   D  ...
# 20  E0  25/08/2018    Arsenal  West Ham     3     1   H     1     1   D  ...
# 38  E0  02/09/2018    Cardiff   Arsenal     2     3   A     1     1   D  ...
# 44  E0  15/09/2018  Newcastle   Arsenal     1     2   A     0     0   D  ...
#
#    HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 7    3    8  11  14   2   9   2   2   0   0
# 11  11    6  12   9   5   1   0   2   0   0
# 20  10    5  16  13  10   2   1   3   0   0
# 38   3   11  12  14   3   9   3   4   0   0
# 44   2    2  13  11  10   4   0   0   0   0
#
# [5 rows x 23 columns]

# %%
# Shape of the Arsenal data: Should be 38 - number of games in a single season.
total_games, total_features = arsenal_data.shape
print("The total number of games played by Arsenal both HOME and AWAY in 2018-2019 Premier League Season - {}"
     .format(total_games))
# Out:
# The total number of games played by Arsenal both HOME and AWAY in 2018-2019 Premier League Season - 38

# %%
home_data = arsenal_data[arsenal_data['HomeTeam'] == 'Arsenal']
home_data.head()
# Out:
#    Div        Date HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 7   E0  12/08/2018  Arsenal   Man City     0     2   A     0     1   A  ...
# 20  E0  25/08/2018  Arsenal   West Ham     3     1   H     1     1   D  ...
# 58  E0  23/09/2018  Arsenal    Everton     2     0   H     0     0   D  ...
# 60  E0  29/09/2018  Arsenal    Watford     2     0   H     0     0   D  ...
# 89  E0  22/10/2018  Arsenal  Leicester     3     1   H     1     1   D  ...
#
#    HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 7    3    8  11  14   2   9   2   2   0   0
# 20  10    5  16  13  10   2   1   3   0   0
# 58   5    6  17  12   5   9   2   1   0   0
# 60   2    4  11  17   6   6   2   2   0   0
# 89   6    2  10  10   6   4   2   2   0   0
#
# [5 rows x 23 columns]

# %%
home_games = home_data.shape[0]
print("The number of games played by Arsenal at HOME in 2018-2019 Premier League Season - {}"
     .format(home_games))
# Out:
# The number of games played by Arsenal at HOME in 2018-2019 Premier League Season - 19

# %%
# We can easily describe the statistics using .describe() method.
home_data.describe()
# Out:
#             FTHG       FTAG       HTHG       HTAG         HS         AS  \
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean    2.210526   0.842105   0.736842   0.421053  13.473684  11.421053
# std     1.228321   0.834210   0.733493   0.606977   4.128067   3.906061
# min     0.000000   0.000000   0.000000   0.000000   7.000000   3.000000
# 25%     1.500000   0.000000   0.000000   0.000000  10.000000   9.000000
# 50%     2.000000   1.000000   1.000000   0.000000  13.000000  12.000000
# 75%     3.000000   1.000000   1.000000   1.000000  16.000000  13.000000
# max     5.000000   3.000000   2.000000   2.000000  22.000000  19.000000
#
#              HST        AST         HF         AF         HC         AC  \
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean    5.052632   3.947368  11.473684  13.473684   6.736842   4.368421
# std     2.247806   2.146669   3.025235   3.272247   3.347339   2.476793
# ...

# %%
# Average number of goals scored by Arsenal at HOME:
print("The average number of goals scored by Arsenal at HOME - {}".format(home_data['FTHG'].mean()))
# Out:
# The average number of goals scored by Arsenal at HOME - 2.210526315789474

# %%
# Average number of goals conceded by Arsenal at HOME:
print("The average number of goals conceded by Arsenal at HOME - {}".format(home_data['FTAG'].mean()))
# Out:
# The average number of goals conceded by Arsenal at HOME - 0.8421052631578947

# %%
# Total number of goals scored by Arsenal at HOME:
print("The total number of goals scored by Arsenal at HOME - {}".format(home_data['FTHG'].sum()))
# Out:
# The total number of goals scored by Arsenal at HOME - 42

# %%
# Total number of goals conceded by Arsenal at HOME:
print("The total number of goals conceded by Arsenal at HOME - {}".format(home_data['FTAG'].sum()))
# Out:
# The total number of goals conceded by Arsenal at HOME - 16

# %%
# Average number of shots by Arsenal at HOME:
print("The average number of shots by Arsenal at HOME - {}".format(home_data['HS'].mean()))
# Out:
# The average number of shots by Arsenal at HOME - 13.473684210526315

# %%
# Average number of shots conceded by Arsenal at HOME:
print("The average number of shots conceded by Arsenal at HOME - {}".format(home_data['AS'].mean()))
# Out:
# The average number of shots conceded by Arsenal at HOME - 11.421052631578947

# %%
# The total number of shots

# %%
# Calculate Arsenal summary statistics
arsenal_data.describe()
# This data is pretty useless considering that we don't know who is home and who is away. 
# Let's do the analysis for all HOME games for arsenal
# Out:
#             FTHG       FTAG       HTHG       HTAG         HS         AS  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean    2.026316   1.236842   0.894737   0.578947  14.026316  11.236842
# std     1.218924   1.101208   0.952648   0.642275   4.790118   4.226264
# min     0.000000   0.000000   0.000000   0.000000   4.000000   3.000000
# 25%     1.000000   0.250000   0.000000   0.000000  11.000000   8.250000
# 50%     2.000000   1.000000   1.000000   0.500000  13.500000  11.000000
# 75%     3.000000   2.000000   1.000000   1.000000  16.000000  13.000000
# max     5.000000   5.000000   4.000000   2.000000  24.000000  20.000000
#
#              HST        AST         HF         AF  ...   BbAv<2.5       BbAH  \
# count  38.000000  38.000000  38.000000  38.000000  ...  38.000000  38.000000
# mean    5.368421   3.921053  11.342105  11.842105  ...   2.424474  20.815789
# std     2.813299   2.294312   2.821503   3.620709  ...   0.263569   1.539661
# ...
